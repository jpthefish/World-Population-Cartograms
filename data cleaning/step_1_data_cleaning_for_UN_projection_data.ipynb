# %%
import pandas as pd
import numpy as np

# %%
# Create the code to read a csv file 
dtype_spec = {2: str, 3: str, 4: str, 7: str}

population_df = pd.read_csv('WPP2024_TotalPopulationBySex.csv', dtype=dtype_spec)

# %%
population_df.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 1        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 2        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 3        NaN   5507   NaN       NaN       NaN        NaN        NaN
# 4        NaN   5507   NaN       NaN       NaN        NaN        NaN
#
#   LocTypeName  ParentID                           Location  VarID Variant  \
# 0         NaN       NaN  ADB region: Central and West Asia      2  Medium
# 1         NaN       NaN  ADB region: Central and West Asia      2  Medium
# 2         NaN       NaN  ADB region: Central and West Asia      2  Medium
# 3         NaN       NaN  ADB region: Central and West Asia      2  Medium
# 4         NaN       NaN  ADB region: Central and West Asia      2  Medium
#
#    Time  MidPeriod    PopMale  PopFemale   PopTotal  PopDensity
# ...

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720210 entries, 0 to 720209
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   SortOrder    468660 non-null  float64
#  1   LocID        720210 non-null  int64
#  2   Notes        113880 non-null  object
#  3   ISO3_code    346020 non-null  object
#  4   ISO2_code    344560 non-null  object
#  5   SDMX_code    416100 non-null  float64
#  6   LocTypeID    468660 non-null  float64
#  7   LocTypeName  468660 non-null  object
#  8   ParentID     468660 non-null  float64
#  9   Location     720210 non-null  object
#  10  VarID        720210 non-null  int64
#  11  Variant      720210 non-null  object
#  12  Time         720210 non-null  int64
#  13  MidPeriod    720210 non-null  float64
#  14  PopMale      720210 non-null  float64
#  15  PopFemale    720210 non-null  float64
#  16  PopTotal     720210 non-null  float64
# ...

# %%
population_df.drop(columns=['PopMale', 'PopFemale', 'PopDensity'], inplace=True)

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720210 entries, 0 to 720209
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   SortOrder    468660 non-null  float64
#  1   LocID        720210 non-null  int64
#  2   Notes        113880 non-null  object
#  3   ISO3_code    346020 non-null  object
#  4   ISO2_code    344560 non-null  object
#  5   SDMX_code    416100 non-null  float64
#  6   LocTypeID    468660 non-null  float64
#  7   LocTypeName  468660 non-null  object
#  8   ParentID     468660 non-null  float64
#  9   Location     720210 non-null  object
#  10  VarID        720210 non-null  int64
#  11  Variant      720210 non-null  object
#  12  Time         720210 non-null  int64
#  13  MidPeriod    720210 non-null  float64
#  14  PopTotal     720210 non-null  float64
# dtypes: float64(6), int64(3), object(6)
# memory usage: 82.4+ MB

# %%
variants = population_df['Variant'].unique()
print(variants)
# Out:
# ['Medium' 'High' 'Low' 'Constant fertility' 'Instant replacement'
#  'Zero migration' 'Constant mortality' 'No change' 'Momentum'
#  'Instant replacement zero migration' 'No fertility below age 18'
#  'Accelerated ABR decline' 'Accelarated ABR decline w/rec.' 'Median PI'
#  'Upper 80 PI' 'Lower 80 PI' 'Upper 95 PI' 'Lower 95 PI']

# %%
population_df.drop(columns=['Notes', 'SDMX_code'], inplace=True)

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720210 entries, 0 to 720209
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   SortOrder    468660 non-null  float64
#  1   LocID        720210 non-null  int64
#  2   ISO3_code    346020 non-null  object
#  3   ISO2_code    344560 non-null  object
#  4   LocTypeID    468660 non-null  float64
#  5   LocTypeName  468660 non-null  object
#  6   ParentID     468660 non-null  float64
#  7   Location     720210 non-null  object
#  8   VarID        720210 non-null  int64
#  9   Variant      720210 non-null  object
#  10  Time         720210 non-null  int64
#  11  MidPeriod    720210 non-null  float64
#  12  PopTotal     720210 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 71.4+ MB

# %%
population_df.to_csv('modified_UN_population_data_1950_to_2100.csv', index=False)

# %%
dtype_spec = {2: str, 3: str, 5: str}
population_df = pd.read_csv('modified_UN_population_data_1950_to_2100.csv', dtype=dtype_spec)

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720210 entries, 0 to 720209
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   SortOrder    468660 non-null  float64
#  1   LocID        720210 non-null  int64
#  2   ISO3_code    346020 non-null  object
#  3   ISO2_code    344560 non-null  object
#  4   LocTypeID    468660 non-null  float64
#  5   LocTypeName  468660 non-null  object
#  6   ParentID     468660 non-null  float64
#  7   Location     720210 non-null  object
#  8   VarID        720210 non-null  int64
#  9   Variant      720210 non-null  object
#  10  Time         720210 non-null  int64
#  11  MidPeriod    720210 non-null  float64
#  12  PopTotal     720210 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 71.4+ MB

# %%
population_df.head()
# Out:
#    SortOrder  LocID ISO3_code ISO2_code  LocTypeID LocTypeName  ParentID  \
# 0        NaN   5507       NaN       NaN        NaN         NaN       NaN
# 1        NaN   5507       NaN       NaN        NaN         NaN       NaN
# 2        NaN   5507       NaN       NaN        NaN         NaN       NaN
# 3        NaN   5507       NaN       NaN        NaN         NaN       NaN
# 4        NaN   5507       NaN       NaN        NaN         NaN       NaN
#
#                             Location  VarID Variant  Time  MidPeriod  \
# 0  ADB region: Central and West Asia      2  Medium  1950     1950.5
# 1  ADB region: Central and West Asia      2  Medium  1951     1951.5
# 2  ADB region: Central and West Asia      2  Medium  1952     1952.5
# 3  ADB region: Central and West Asia      2  Medium  1953     1953.5
# 4  ADB region: Central and West Asia      2  Medium  1954     1954.5
#
#     PopTotal
# 0  69213.424
# 1  70682.760
# 2  72238.716
# 3  73876.364
# 4  75600.454
